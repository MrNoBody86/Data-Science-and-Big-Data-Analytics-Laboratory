# %% [markdown]
# <a href="https://colab.research.google.com/github/MrNoBody86/Data-Science-and-Big-Data-Analytics-Laboratory/blob/main/A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Wrangling II
# Create an “Academic performance” dataset of students and perform the following operations using
# Python.
# 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them.
# 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable
# techniques to deal with them.
# 3. Apply data transformations on at least one of the variables. The purpose of this
# transformation should be one of the following reasons: to change the scale for better
# understanding of the variable, to convert a non-linear relation into a linear one, or to
# decrease the skewness and convert the distribution into a normal distribution.

# %%
import pandas as pd
import numpy as np

Student_data = pd.read_csv("/content/dataset.csv")

Student_data
# Out:
#            Timestamp              Name                       Email Roll no  \
# 0   24-01-2024 14:30    Isabella Jones    isabella.jones@email.com   IJ016
# 1   24-01-2024 14:45        Noah Jones        noah.jones@email.com   NJ028
# 2   24-01-2024 15:00   Olivia Anderson   olivia.anderson@email.com   OA029
# 3   24-01-2024 15:15        Liam Smith        liam.smith@email.com   LS030
# 4   24-01-2024 15:30        Emma Jones        emma.jones@email.com   EJ031
# 5   24-01-2024 15:45    Jackson Miller    jackson.miller@email.com   JM032
# 6   24-01-2024 16:00      Sophie Brown      sophie.brown@email.com   SB033
# 7   24-01-2024 16:15   Oliver Anderson   oliver.anderson@email.com   OA034
# 8   24-01-2024 16:30       Chloe White       chloe.white@email.com   CW035
# 9   24-01-2024 16:45       Jacob Brown       jacob.brown@email.com   JB036
# 10  24-01-2024 17:00      Sophia Smith      sophia.smith@email.com   SS037
# ...

# %%
Student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           47 non-null     object
#  1   Name                47 non-null     object
#  2   Email               47 non-null     object
#  3   Roll no             47 non-null     object
#  4   PRN No.             47 non-null     object
#  5   Mobile No.          47 non-null     int64
#  6   First year: Sem 1   46 non-null     float64
#  7   First year: Sem 2   44 non-null     float64
#  8   Second year: Sem 1  45 non-null     float64
#  9   Second year: Sem 2  47 non-null     int64
#  10  Result              44 non-null     object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 4.2+ KB

# %%
Student_data.head()
# Out:
#           Timestamp             Name                      Email Roll no  \
# 0  24-01-2024 14:30   Isabella Jones   isabella.jones@email.com   IJ016
# 1  24-01-2024 14:45       Noah Jones       noah.jones@email.com   NJ028
# 2  24-01-2024 15:00  Olivia Anderson  olivia.anderson@email.com   OA029
# 3  24-01-2024 15:15       Liam Smith       liam.smith@email.com   LS030
# 4  24-01-2024 15:30       Emma Jones       emma.jones@email.com   EJ031
#
#   PRN No.  Mobile No.  First year: Sem 1  First year: Sem 2  \
# 0  PRN016  9988776655               85.0               92.0
# 1  PRN028  1122335566               90.0               94.0
# 2  PRN029  9988776655               69.0               88.0
# 3  PRN030  5566778899               92.0               85.0
# 4  PRN031  9988776655               87.0                NaN
#
#    Second year: Sem 1  Second year: Sem 2 Result
# 0                87.0                  89   Pass
# 1                78.0                  85   Pass
# ...

# %%
Student_data.describe(include="all")
# Out:
#                Timestamp            Name                     Email Roll no  \
# count                 47              47                        47      47
# unique                42              47                        47      47
# top     24-01-2024 14:30  Isabella Jones  isabella.jones@email.com   IJ016
# freq                   2               1                         1       1
# mean                 NaN             NaN                       NaN     NaN
# std                  NaN             NaN                       NaN     NaN
# min                  NaN             NaN                       NaN     NaN
# 25%                  NaN             NaN                       NaN     NaN
# 50%                  NaN             NaN                       NaN     NaN
# 75%                  NaN             NaN                       NaN     NaN
# max                  NaN             NaN                       NaN     NaN
#
# ...

# %%
Student_data.shape
# Out:
# (47, 11)

# %%
Student_data.dtypes
# Out:
# Timestamp              object
# Name                   object
# Email                  object
# Roll no                object
# PRN No.                object
# Mobile No.              int64
# First year: Sem 1     float64
# First year: Sem 2     float64
# Second year: Sem 1    float64
# Second year: Sem 2      int64
# Result                 object
# dtype: object

# %%
Student_data.columns
# Out:
# Index(['Timestamp', 'Name', 'Email', 'Roll no', 'PRN No.', 'Mobile No.',
#        'First year: Sem 1', 'First year: Sem 2', 'Second year: Sem 1',
#        'Second year: Sem 2', 'Result'],
#       dtype='object')

# %%
Student_data[0:5]
# Out:
#           Timestamp             Name                      Email Roll no  \
# 0  24-01-2024 14:30   Isabella Jones   isabella.jones@email.com   IJ016
# 1  24-01-2024 14:45       Noah Jones       noah.jones@email.com   NJ028
# 2  24-01-2024 15:00  Olivia Anderson  olivia.anderson@email.com   OA029
# 3  24-01-2024 15:15       Liam Smith       liam.smith@email.com   LS030
# 4  24-01-2024 15:30       Emma Jones       emma.jones@email.com   EJ031
#
#   PRN No.  Mobile No.  First year: Sem 1  First year: Sem 2  \
# 0  PRN016  9988776655               85.0               92.0
# 1  PRN028  1122335566               90.0               94.0
# 2  PRN029  9988776655               69.0               88.0
# 3  PRN030  5566778899               92.0               85.0
# 4  PRN031  9988776655               87.0                NaN
#
#    Second year: Sem 1  Second year: Sem 2 Result
# 0                87.0                  89   Pass
# 1                78.0                  85   Pass
# ...

# %%
Student_data.loc[0:2]
# Out:
#           Timestamp             Name                      Email Roll no  \
# 0  24-01-2024 14:30   Isabella Jones   isabella.jones@email.com   IJ016
# 1  24-01-2024 14:45       Noah Jones       noah.jones@email.com   NJ028
# 2  24-01-2024 15:00  Olivia Anderson  olivia.anderson@email.com   OA029
#
#   PRN No.  Mobile No.  First year: Sem 1  First year: Sem 2  \
# 0  PRN016  9988776655               85.0               92.0
# 1  PRN028  1122335566               90.0               94.0
# 2  PRN029  9988776655               69.0               88.0
#
#    Second year: Sem 1  Second year: Sem 2 Result
# 0                87.0                  89   Pass
# 1                78.0                  85   Pass
# 2                93.0                  92    NaN

# %%
Student_data.loc[0:2,"First year: Sem 1":"Second year: Sem 2"]
# Out:
#    First year: Sem 1  First year: Sem 2  Second year: Sem 1  \
# 0               85.0               92.0                87.0
# 1               90.0               94.0                78.0
# 2               69.0               88.0                93.0
#
#    Second year: Sem 2
# 0                  89
# 1                  85
# 2                  92

# %%
Student_data.iloc[1:3]
# Out:
#           Timestamp             Name                      Email Roll no  \
# 1  24-01-2024 14:45       Noah Jones       noah.jones@email.com   NJ028
# 2  24-01-2024 15:00  Olivia Anderson  olivia.anderson@email.com   OA029
#
#   PRN No.  Mobile No.  First year: Sem 1  First year: Sem 2  \
# 1  PRN028  1122335566               90.0               94.0
# 2  PRN029  9988776655               69.0               88.0
#
#    Second year: Sem 1  Second year: Sem 2 Result
# 1                78.0                  85   Pass
# 2                93.0                  92    NaN

# %%
Student_data.iloc[1:5,1:5]
# Out:
#               Name                      Email Roll no PRN No.
# 1       Noah Jones       noah.jones@email.com   NJ028  PRN028
# 2  Olivia Anderson  olivia.anderson@email.com   OA029  PRN029
# 3       Liam Smith       liam.smith@email.com   LS030  PRN030
# 4       Emma Jones       emma.jones@email.com   EJ031  PRN031

# %% [markdown]
# ### 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or inconsistencies, use any of the suitable techniques to deal with them.

# %%
Student_data.isnull()
# Out:
#     Timestamp   Name  Email  Roll no  PRN No.  Mobile No.  First year: Sem 1  \
# 0       False  False  False    False    False       False              False
# 1       False  False  False    False    False       False              False
# 2       False  False  False    False    False       False              False
# 3       False  False  False    False    False       False              False
# 4       False  False  False    False    False       False              False
# 5       False  False  False    False    False       False               True
# 6       False  False  False    False    False       False              False
# 7       False  False  False    False    False       False              False
# 8       False  False  False    False    False       False              False
# 9       False  False  False    False    False       False              False
# 10      False  False  False    False    False       False              False
# ...

# %%
Student_data.isna()
# Out:
#     Timestamp   Name  Email  Roll no  PRN No.  Mobile No.  First year: Sem 1  \
# 0       False  False  False    False    False       False              False
# 1       False  False  False    False    False       False              False
# 2       False  False  False    False    False       False              False
# 3       False  False  False    False    False       False              False
# 4       False  False  False    False    False       False              False
# 5       False  False  False    False    False       False               True
# 6       False  False  False    False    False       False              False
# 7       False  False  False    False    False       False              False
# 8       False  False  False    False    False       False              False
# 9       False  False  False    False    False       False              False
# 10      False  False  False    False    False       False              False
# ...

# %%
Student_data.isnull().any()
# Out:
# Timestamp             False
# Name                  False
# Email                 False
# Roll no               False
# PRN No.               False
# Mobile No.            False
# First year: Sem 1      True
# First year: Sem 2      True
# Second year: Sem 1     True
# Second year: Sem 2    False
# Result                 True
# dtype: bool

# %%
Student_data.isnull().sum()
# Out:
# Timestamp             0
# Name                  0
# Email                 0
# Roll no               0
# PRN No.               0
# Mobile No.            0
# First year: Sem 1     1
# First year: Sem 2     3
# Second year: Sem 1    2
# Second year: Sem 2    0
# Result                3
# dtype: int64

# %% [markdown]
# Make a list of column having missing value

# %%
cols_with_na = []

for col in Student_data.columns :
    if Student_data[col].isna().any():
        cols_with_na.append(col)
cols_with_na
# Out:
# ['First year: Sem 1', 'First year: Sem 2', 'Second year: Sem 1', 'Result']

# %% [markdown]
# 4.Deleting null values using dropna() method
#
# In order to drop null values from a dataframe, dropna() function is used. This
# function drops Rows/Columns of datasets with Null values in different ways.
# 1. Dropping rows with at least 1 null value
# 2. Dropping rows if all values in that row are missing
# 3. Dropping columns with at least 1 null value.
# 4. Dropping Rows with at least 1 null value in CSV file

# %%
Student_data.dropna(axis = 0) #axis = 1 for column
# Out:
#            Timestamp              Name                       Email Roll no  \
# 0   24-01-2024 14:30    Isabella Jones    isabella.jones@email.com   IJ016
# 1   24-01-2024 14:45        Noah Jones        noah.jones@email.com   NJ028
# 3   24-01-2024 15:15        Liam Smith        liam.smith@email.com   LS030
# 8   24-01-2024 16:30       Chloe White       chloe.white@email.com   CW035
# 9   24-01-2024 16:45       Jacob Brown       jacob.brown@email.com   JB036
# 10  24-01-2024 17:00      Sophia Smith      sophia.smith@email.com   SS037
# 11  24-01-2024 17:15       Ethan White       ethan.white@email.com   EW038
# 12  24-01-2024 17:45     Jackson Jones     jackson.jones@email.com   JJ040
# 13  24-01-2024 18:00      Chloe Miller      chloe.miller@email.com   CM041
# 14  24-01-2024 18:15       Jacob Smith       jacob.smith@email.com   JS042
# 17  24-01-2024 19:00     Olivia Miller     olivia.miller@email.com   OM045
# ...

# %%
Student_data.dropna(how="all")
# Out:
#            Timestamp              Name                       Email Roll no  \
# 0   24-01-2024 14:30    Isabella Jones    isabella.jones@email.com   IJ016
# 1   24-01-2024 14:45        Noah Jones        noah.jones@email.com   NJ028
# 2   24-01-2024 15:00   Olivia Anderson   olivia.anderson@email.com   OA029
# 3   24-01-2024 15:15        Liam Smith        liam.smith@email.com   LS030
# 4   24-01-2024 15:30        Emma Jones        emma.jones@email.com   EJ031
# 5   24-01-2024 15:45    Jackson Miller    jackson.miller@email.com   JM032
# 6   24-01-2024 16:00      Sophie Brown      sophie.brown@email.com   SB033
# 7   24-01-2024 16:15   Oliver Anderson   oliver.anderson@email.com   OA034
# 8   24-01-2024 16:30       Chloe White       chloe.white@email.com   CW035
# 9   24-01-2024 16:45       Jacob Brown       jacob.brown@email.com   JB036
# 10  24-01-2024 17:00      Sophia Smith      sophia.smith@email.com   SS037
# ...

# %% [markdown]
# Filling missing values using dropna(), fillna(), replace() :
# 1. replacing null values with NaN

# %%
Student_data.replace(np.nan,value=0)
# Out:
#            Timestamp              Name                       Email Roll no  \
# 0   24-01-2024 14:30    Isabella Jones    isabella.jones@email.com   IJ016
# 1   24-01-2024 14:45        Noah Jones        noah.jones@email.com   NJ028
# 2   24-01-2024 15:00   Olivia Anderson   olivia.anderson@email.com   OA029
# 3   24-01-2024 15:15        Liam Smith        liam.smith@email.com   LS030
# 4   24-01-2024 15:30        Emma Jones        emma.jones@email.com   EJ031
# 5   24-01-2024 15:45    Jackson Miller    jackson.miller@email.com   JM032
# 6   24-01-2024 16:00      Sophie Brown      sophie.brown@email.com   SB033
# 7   24-01-2024 16:15   Oliver Anderson   oliver.anderson@email.com   OA034
# 8   24-01-2024 16:30       Chloe White       chloe.white@email.com   CW035
# 9   24-01-2024 16:45       Jacob Brown       jacob.brown@email.com   JB036
# 10  24-01-2024 17:00      Sophia Smith      sophia.smith@email.com   SS037
# ...

# %%
Student_data.fillna(1)
# Out:
#            Timestamp              Name                       Email Roll no  \
# 0   24-01-2024 14:30    Isabella Jones    isabella.jones@email.com   IJ016
# 1   24-01-2024 14:45        Noah Jones        noah.jones@email.com   NJ028
# 2   24-01-2024 15:00   Olivia Anderson   olivia.anderson@email.com   OA029
# 3   24-01-2024 15:15        Liam Smith        liam.smith@email.com   LS030
# 4   24-01-2024 15:30        Emma Jones        emma.jones@email.com   EJ031
# 5   24-01-2024 15:45    Jackson Miller    jackson.miller@email.com   JM032
# 6   24-01-2024 16:00      Sophie Brown      sophie.brown@email.com   SB033
# 7   24-01-2024 16:15   Oliver Anderson   oliver.anderson@email.com   OA034
# 8   24-01-2024 16:30       Chloe White       chloe.white@email.com   CW035
# 9   24-01-2024 16:45       Jacob Brown       jacob.brown@email.com   JB036
# 10  24-01-2024 17:00      Sophia Smith      sophia.smith@email.com   SS037
# ...

# %%
Student_data['First year: Sem 1'] = Student_data['First year: Sem 1'].fillna(Student_data['First year: Sem 1'].mean())
Student_data['First year: Sem 1']
# Out:
# 0     85.000000
# 1     90.000000
# 2     69.000000
# 3     92.000000
# 4     87.000000
# 5     86.869565
# 6     89.000000
# 7     94.000000
# 8     88.000000
# 9     92.000000
# 10    80.000000
# 11    91.000000
# 12    92.000000
# 13    89.000000
# 14    91.000000
# 15    92.000000
# 16    80.000000
# 17    87.000000
# 18    90.000000
# 19    79.000000
# 20    94.000000
# 21    78.000000
# 22    85.000000
# 23    78.000000
# 24    92.000000
# 25    80.000000
# 26    88.000000
# 27    75.000000
# 28    90.000000
# 29    85.000000
# 30    93.000000
# 31    87.000000
# 32    82.000000
# 33    89.000000
# 34    91.000000
# 35    78.000000
# 36    95.000000
# 37    84.000000
# 38    92.000000
# 39    87.000000
# 40    90.000000
# 41    94.000000
# 42    78.000000
# 43    89.000000
# 44    91.000000
# 45    88.000000
# 46    86.000000
# Name: First year: Sem 1, dtype: float64

# %%
Student_data['First year: Sem 2'] = Student_data['First year: Sem 2'].fillna(Student_data['First year: Sem 2'].median())
Student_data['First year: Sem 2']
# Out:
# 0     92.0
# 1     94.0
# 2     88.0
# 3     85.0
# 4     88.0
# 5     89.0
# 6     87.0
# 7     88.0
# 8     85.0
# 9     88.0
# 10    92.0
# 11    89.0
# 12    40.0
# 13    85.0
# 14    92.0
# 15    85.0
# 16    88.0
# 17    88.0
# 18    94.0
# 19    88.0
# 20    88.0
# 21    90.0
# 22    90.0
# 23    88.0
# 24    85.0
# 25    92.0
# 26    78.0
# 27    85.0
# 28    94.0
# 29    88.0
# 30    95.0
# 31    90.0
# 32    89.0
# 33    91.0
# 34    88.0
# 35    80.0
# 36    94.0
# 37    87.0
# 38    90.0
# 39    88.0
# 40    82.0
# 41    88.0
# 42    55.0
# 43    85.0
# 44    92.0
# 45    89.0
# 46    87.0
# Name: First year: Sem 2, dtype: float64

# %%
Student_data['Second year: Sem 1'] = Student_data['Second year: Sem 1'].fillna(Student_data['Second year: Sem 1'].max())
Student_data['Second year: Sem 1']
# Out:
# 0     87.0
# 1     78.0
# 2     93.0
# 3     88.0
# 4     91.0
# 5     92.0
# 6     95.0
# 7     88.0
# 8     94.0
# 9     87.0
# 10    91.0
# 11    85.0
# 12    78.0
# 13    94.0
# 14    87.0
# 15    88.0
# 16    91.0
# 17    91.0
# 18    78.0
# 19    93.0
# 20    95.0
# 21    85.0
# 22    78.0
# 23    95.0
# 24    89.0
# 25    85.0
# 26    93.0
# 27    90.0
# 28    80.0
# 29    92.0
# 30    91.0
# 31    84.0
# 32    88.0
# 33    85.0
# 34    92.0
# 35    94.0
# 36    80.0
# 37    92.0
# 38    78.0
# 39    91.0
# 40    89.0
# 41    83.0
# 42    85.0
# 43    94.0
# 44    87.0
# 45    92.0
# 46    91.0
# Name: Second year: Sem 1, dtype: float64

# %%
Student_data['Result'] = Student_data['Result'].fillna(Student_data['Result'].mode()[0])
Student_data['Result']
# Out:
# 0     Pass
# 1     Pass
# 2     Pass
# 3     Pass
# 4     Fail
# 5     Fail
# 6     Fail
# 7     Fail
# 8     Pass
# 9     Pass
# 10    Pass
# 11    Pass
# 12    Fail
# 13    Pass
# 14    Pass
# 15    Pass
# 16    Fail
# 17    Pass
# 18    Pass
# 19    Pass
# 20    Fail
# 21    Pass
# 22    Pass
# 23    Pass
# 24    Pass
# 25    Pass
# 26    Pass
# 27    Pass
# 28    Pass
# 29    Pass
# 30    Pass
# 31    Pass
# 32    Pass
# 33    Pass
# 34    Pass
# 35    Pass
# 36    Pass
# 37    Pass
# 38    Pass
# 39    Pass
# 40    Pass
# 41    Pass
# 42    Pass
# 43    Pass
# 44    Pass
# 45    Pass
# 46    Pass
# Name: Result, dtype: object

# %%
Student_data.isnull().sum()
# Out:
# Timestamp             0
# Name                  0
# Email                 0
# Roll no               0
# PRN No.               0
# Mobile No.            0
# First year: Sem 1     0
# First year: Sem 2     0
# Second year: Sem 1    0
# Second year: Sem 2    0
# Result                0
# dtype: int64

# %% [markdown]
# #B. Identification and Handling of Outliers
#
# Identification of Outliers
#
# an Outlier is an observation in a given dataset that lies far from the rest
# of the observations. That means an outlier is vastly larger or smaller than the remaining values in the set.

# %% [markdown]
# Detecting Outliers
# 1. Detecting outliers using Boxplot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(Student_data['First year: Sem 2'])
# Out:
# <Axes: ylabel='First year: Sem 2'>

# %%
sns.boxplot(Student_data['First year: Sem 1'])
# Out:
# <Axes: ylabel='First year: Sem 1'>

# %%
sns.boxplot(Student_data['Second year: Sem 1'])
# Out:
# <Axes: ylabel='Second year: Sem 1'>

# %%
sns.boxplot(x =Student_data['Second year: Sem 2'])
# Out:
# <Axes: xlabel='Second year: Sem 2'>

# %%
Student_data.boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
df_list = ['First year: Sem 1','First year: Sem 2','Second year: Sem 2','Second year: Sem 1']
fig, axes = plt.subplots(2, 2)
fig.set_dpi(120)
count=0
for r in range(2):
  for c in range(2):
    _ = Student_data[df_list[count]].plot(kind = 'box', ax=axes[r,c])
    count += 1

# %% [markdown]
# 3.Detecting outliers using Inter Quantile Range(IQR):

# %%
Q1 = Student_data['First year: Sem 2'].quantile(0.25)
Q3 = Student_data['First year: Sem 2'].quantile(0.75)
IQR = Q3 - Q1
Lower_limit = Q1 - 1.5 * IQR
Upper_limit = Q3 + 1.5 * IQR
print(f'Q1 = {Q1}, Q3 = {Q3}, IQR = {IQR}, Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Q1 = 86.0, Q3 = 90.0, IQR = 4.0, Lower_limit = 80.0, Upper_limit = 96.0

# %%
Student_data[(Student_data['First year: Sem 2'] < Lower_limit) | (Student_data['First year: Sem 2'] > Upper_limit)] # outlier data
# Out:
#            Timestamp            Name                     Email Roll no  \
# 12  24-01-2024 17:45   Jackson Jones   jackson.jones@email.com   JJ040
# 26  24-01-2024 10:00  Michael Miller  michael.miller@email.com   MM005
# 42  24-01-2024 14:30    Oliver Jones    oliver.jones@email.com   OJ023
#
#    PRN No.  Mobile No.  First year: Sem 1  First year: Sem 2  \
# 12  PRN040  3344556677               92.0               40.0
# 26  PRN005  1122337788               88.0               78.0
# 42  PRN023  3344556677               78.0               55.0
#
#     Second year: Sem 1  Second year: Sem 2 Result
# 12                78.0                  92   Fail
# 26                93.0                  91   Pass
# 42                85.0                  92   Pass

# %% [markdown]
# Handling of Outliers
#
# 1.removing the outlier:

# %%
outliers=[]
for i in Student_data['First year: Sem 2']:
  if i<Lower_limit or i>Upper_limit:
    outliers.append(i)
print("outliers are",outliers)
# Out:
# outliers are [40.0, 78.0, 55.0]

# %%
Upper_limit
# Out:
# 96.0

# %%
Lower_limit
# Out:
# 80.0

# %%
Student_data[Student_data['First year: Sem 2']<Lower_limit].index
# Out:
# Int64Index([12, 26, 42], dtype='int64')

# %%
df = Student_data.drop(Student_data[Student_data['First year: Sem 2']<Lower_limit].index)

# %%
df.shape
# Out:
# (44, 11)

# %%
df1 = Student_data[Student_data['First year: Sem 2']<Lower_limit]
df1
# Out:
#            Timestamp            Name                     Email Roll no  \
# 12  24-01-2024 17:45   Jackson Jones   jackson.jones@email.com   JJ040
# 26  24-01-2024 10:00  Michael Miller  michael.miller@email.com   MM005
# 42  24-01-2024 14:30    Oliver Jones    oliver.jones@email.com   OJ023
#
#    PRN No.  Mobile No.  First year: Sem 1  First year: Sem 2  \
# 12  PRN040  3344556677               92.0               40.0
# 26  PRN005  1122337788               88.0               78.0
# 42  PRN023  3344556677               78.0               55.0
#
#     Second year: Sem 1  Second year: Sem 2 Result
# 12                78.0                  92   Fail
# 26                93.0                  91   Pass
# 42                85.0                  92   Pass

# %%
sns.kdeplot(Student_data['First year: Sem 2'])
# Out:
# <Axes: xlabel='First year: Sem 2', ylabel='Density'>

# %%
sns.kdeplot(Student_data['First year: Sem 2'])
# Out:
# <Axes: xlabel='First year: Sem 2', ylabel='Density'>

# %%
Student_data['First year: Sem 2']
# Out:
# 0     92.0
# 1     94.0
# 2     88.0
# 3     85.0
# 4     88.0
# 5     89.0
# 6     87.0
# 7     88.0
# 8     85.0
# 9     88.0
# 10    92.0
# 11    89.0
# 12    40.0
# 13    85.0
# 14    92.0
# 15    85.0
# 16    88.0
# 17    88.0
# 18    94.0
# 19    88.0
# 20    88.0
# 21    90.0
# 22    90.0
# 23    88.0
# 24    85.0
# 25    92.0
# 26    78.0
# 27    85.0
# 28    94.0
# 29    88.0
# 30    95.0
# 31    90.0
# 32    89.0
# 33    91.0
# 34    88.0
# 35    80.0
# 36    94.0
# 37    87.0
# 38    90.0
# 39    88.0
# 40    82.0
# 41    88.0
# 42    55.0
# 43    85.0
# 44    92.0
# 45    89.0
# 46    87.0
# Name: First year: Sem 2, dtype: float64

# %%
log_sem2=np.log(Student_data['First year: Sem 2'])
log_sem2
# Out:
# 0     4.521789
# 1     4.543295
# 2     4.477337
# 3     4.442651
# 4     4.477337
# 5     4.488636
# 6     4.465908
# 7     4.477337
# 8     4.442651
# 9     4.477337
# 10    4.521789
# 11    4.488636
# 12    3.688879
# 13    4.442651
# 14    4.521789
# 15    4.442651
# 16    4.477337
# 17    4.477337
# 18    4.543295
# 19    4.477337
# 20    4.477337
# 21    4.499810
# 22    4.499810
# 23    4.477337
# 24    4.442651
# 25    4.521789
# 26    4.356709
# 27    4.442651
# 28    4.543295
# 29    4.477337
# 30    4.553877
# 31    4.499810
# 32    4.488636
# 33    4.510860
# 34    4.477337
# 35    4.382027
# 36    4.543295
# 37    4.465908
# 38    4.499810
# 39    4.477337
# 40    4.406719
# 41    4.477337
# 42    4.007333
# 43    4.442651
# 44    4.521789
# 45    4.488636
# 46    4.465908
# Name: First year: Sem 2, dtype: float64

# %%
sns.kdeplot(log_sem2)
# Out:
# <Axes: xlabel='First year: Sem 2', ylabel='Density'>

# %% [markdown]
# C. Data Transformation
#
# to change the scale for better understanding of the variable
